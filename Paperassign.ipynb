# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_1 = pd.read_csv(r'C:\Users\gaura\AppData\Local\Temp\Temp1_test.csv.zip\test.csv')
df_1
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000004  P00128942      M  46-50           7             B
# 1       1000009  P00113442      M  26-35          17             C
# 2       1000010  P00288442      F  36-45           1             B
# 3       1000010  P00145342      F  36-45           1             B
# 4       1000011  P00053842      F  26-35           1             C
# ...         ...        ...    ...    ...         ...           ...
# 233594  1006036  P00118942      F  26-35          15             B
# 233595  1006036  P00254642      F  26-35          15             B
# 233596  1006036  P00031842      F  26-35          15             B
# 233597  1006037  P00124742      F  46-50           1             C
# 233598  1006039  P00316642      F  46-50           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               1                   1
# ...

# %%
df_2 = pd.read_csv(r'C:\Users\gaura\AppData\Local\Temp\Temp1_train.csv.zip\train.csv')
df_2
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000001  P00069042      F   0-17          10             A
# 1       1000001  P00248942      F   0-17          10             A
# 2       1000001  P00087842      F   0-17          10             A
# 3       1000001  P00085442      F   0-17          10             A
# 4       1000002  P00285442      M    55+          16             C
# ...         ...        ...    ...    ...         ...           ...
# 550063  1006033  P00372445      M  51-55          13             B
# 550064  1006035  P00375436      F  26-35           1             C
# 550065  1006036  P00375436      F  26-35          15             B
# 550066  1006038  P00375436      F    55+           1             C
# 550067  1006039  P00371644      F  46-50           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# ...

# %%
df_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 233599 entries, 0 to 233598
# Data columns (total 11 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   User_ID                     233599 non-null  int64
#  1   Product_ID                  233599 non-null  object
#  2   Gender                      233599 non-null  object
#  3   Age                         233599 non-null  object
#  4   Occupation                  233599 non-null  int64
#  5   City_Category               233599 non-null  object
#  6   Stay_In_Current_City_Years  233599 non-null  object
#  7   Marital_Status              233599 non-null  int64
#  8   Product_Category_1          233599 non-null  int64
#  9   Product_Category_2          161255 non-null  float64
#  10  Product_Category_3          71037 non-null   float64
# dtypes: float64(2), int64(4), object(5)
# memory usage: 19.6+ MB

# %%
df_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 550068 entries, 0 to 550067
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   User_ID                     550068 non-null  int64
#  1   Product_ID                  550068 non-null  object
#  2   Gender                      550068 non-null  object
#  3   Age                         550068 non-null  object
#  4   Occupation                  550068 non-null  int64
#  5   City_Category               550068 non-null  object
#  6   Stay_In_Current_City_Years  550068 non-null  object
#  7   Marital_Status              550068 non-null  int64
#  8   Product_Category_1          550068 non-null  int64
#  9   Product_Category_2          376430 non-null  float64
#  10  Product_Category_3          166821 non-null  float64
#  11  Purchase                    550068 non-null  int64
# dtypes: float64(2), int64(5), object(5)
# ...

# %%
# Check descriptive statistics
df_1.describe()
# Out:
#             User_ID     Occupation  Marital_Status  Product_Category_1  \
# count  2.335990e+05  233599.000000   233599.000000       233599.000000
# mean   1.003029e+06       8.085407        0.410070            5.276542
# std    1.726505e+03       6.521146        0.491847            3.736380
# min    1.000001e+06       0.000000        0.000000            1.000000
# 25%    1.001527e+06       2.000000        0.000000            1.000000
# 50%    1.003070e+06       7.000000        0.000000            5.000000
# 75%    1.004477e+06      14.000000        1.000000            8.000000
# max    1.006040e+06      20.000000        1.000000           18.000000
#
#        Product_Category_2  Product_Category_3
# count       161255.000000        71037.000000
# mean             9.849586           12.669454
# std              5.094943            4.125944
# min              2.000000            3.000000
# 25%              5.000000            9.000000
# 50%              9.000000           14.000000
# ...

# %%
df_2.describe()
# Out:
#             User_ID     Occupation  Marital_Status  Product_Category_1  \
# count  5.500680e+05  550068.000000   550068.000000       550068.000000
# mean   1.003029e+06       8.076707        0.409653            5.404270
# std    1.727592e+03       6.522660        0.491770            3.936211
# min    1.000001e+06       0.000000        0.000000            1.000000
# 25%    1.001516e+06       2.000000        0.000000            1.000000
# 50%    1.003077e+06       7.000000        0.000000            5.000000
# 75%    1.004478e+06      14.000000        1.000000            8.000000
# max    1.006040e+06      20.000000        1.000000           20.000000
#
#        Product_Category_2  Product_Category_3       Purchase
# count       376430.000000       166821.000000  550068.000000
# mean             9.842329           12.668243    9263.968713
# std              5.086590            4.125338    5023.065394
# min              2.000000            3.000000      12.000000
# ...

# %%
# Check for missing values
df_1.isnull().sum()
# Out:
# User_ID                            0
# Product_ID                         0
# Gender                             0
# Age                                0
# Occupation                         0
# City_Category                      0
# Stay_In_Current_City_Years         0
# Marital_Status                     0
# Product_Category_1                 0
# Product_Category_2             72344
# Product_Category_3            162562
# dtype: int64

# %%
df_2.isnull().sum()
# Out:
# User_ID                            0
# Product_ID                         0
# Gender                             0
# Age                                0
# Occupation                         0
# City_Category                      0
# Stay_In_Current_City_Years         0
# Marital_Status                     0
# Product_Category_1                 0
# Product_Category_2            173638
# Product_Category_3            383247
# Purchase                           0
# dtype: int64

# %%
df_1[df_1.isna().any(axis=1)]
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000004  P00128942      M  46-50           7             B
# 1       1000009  P00113442      M  26-35          17             C
# 2       1000010  P00288442      F  36-45           1             B
# 3       1000010  P00145342      F  36-45           1             B
# 9       1000022  P00067942      M  18-25          15             A
# ...         ...        ...    ...    ...         ...           ...
# 233593  1006036  P00255442      F  26-35          15             B
# 233594  1006036  P00118942      F  26-35          15             B
# 233595  1006036  P00254642      F  26-35          15             B
# 233597  1006037  P00124742      F  46-50           1             C
# 233598  1006039  P00316642      F  46-50           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               1                   1
# ...

# %%
df_2[df_2.isna().any(axis=1)]
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000001  P00069042      F   0-17          10             A
# 2       1000001  P00087842      F   0-17          10             A
# 3       1000001  P00085442      F   0-17          10             A
# 4       1000002  P00285442      M    55+          16             C
# 5       1000003  P00193542      M  26-35          15             A
# ...         ...        ...    ...    ...         ...           ...
# 550063  1006033  P00372445      M  51-55          13             B
# 550064  1006035  P00375436      F  26-35           1             C
# 550065  1006036  P00375436      F  26-35          15             B
# 550066  1006038  P00375436      F    55+           1             C
# 550067  1006039  P00371644      F  46-50           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# ...

# %%
df_1.dropna(how='all')
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000004  P00128942      M  46-50           7             B
# 1       1000009  P00113442      M  26-35          17             C
# 2       1000010  P00288442      F  36-45           1             B
# 3       1000010  P00145342      F  36-45           1             B
# 4       1000011  P00053842      F  26-35           1             C
# ...         ...        ...    ...    ...         ...           ...
# 233594  1006036  P00118942      F  26-35          15             B
# 233595  1006036  P00254642      F  26-35          15             B
# 233596  1006036  P00031842      F  26-35          15             B
# 233597  1006037  P00124742      F  46-50           1             C
# 233598  1006039  P00316642      F  46-50           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               1                   1
# ...

# %%
df_2.dropna(how='all')
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000001  P00069042      F   0-17          10             A
# 1       1000001  P00248942      F   0-17          10             A
# 2       1000001  P00087842      F   0-17          10             A
# 3       1000001  P00085442      F   0-17          10             A
# 4       1000002  P00285442      M    55+          16             C
# ...         ...        ...    ...    ...         ...           ...
# 550063  1006033  P00372445      M  51-55          13             B
# 550064  1006035  P00375436      F  26-35           1             C
# 550065  1006036  P00375436      F  26-35          15             B
# 550066  1006038  P00375436      F    55+           1             C
# 550067  1006039  P00371644      F  46-50           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# ...

# %%
# Check for unique values
df_1.nunique()
# Out:
# User_ID                       5891
# Product_ID                    3491
# Gender                           2
# Age                              7
# Occupation                      21
# City_Category                    3
# Stay_In_Current_City_Years       5
# Marital_Status                   2
# Product_Category_1              18
# Product_Category_2              17
# Product_Category_3              15
# dtype: int64

# %%
df_2.nunique()
# Out:
# User_ID                        5891
# Product_ID                     3631
# Gender                            2
# Age                               7
# Occupation                       21
# City_Category                     3
# Stay_In_Current_City_Years        5
# Marital_Status                    2
# Product_Category_1               20
# Product_Category_2               17
# Product_Category_3               15
# Purchase                      18105
# dtype: int64

# %%
# Perform EDA
sns.pairplot(hue='Gender', data=df_1)
plt.show()
sns.pairplot(hue='Gender', data=df_2)
plt.show()

# %%
# Purchase Distribution with respect to other variables in the dataset
sns.catplot(x="Gender", y="Purchase", data=df_2)
sns.catplot(x="Age", y="Purchase", data=df_2)
sns.catplot(x="City_Category", y="Purchase", data=df_2)

# %%
# Checking for the outliers
plt.figure(figsize=(12, 6))
sns.boxplot(x='Product_Category_1', y='Purchase', data=df_1)
plt.title('Outliers in Purchase by Product Category 1')
plt.xlabel('Product Category 1')
plt.ylabel('Purchase amount')
plt.show()

plt.figure(figsize=(12, 6))
sns.boxplot(x='Product_Category_2', y='Purchase', data=df_1)
plt.title('Outliers in Purchase by Product Category 2')
plt.xlabel('Product Category 2')
plt.ylabel('Purchase amount')
plt.show()

plt.figure(figsize=(12, 6))
sns.boxplot(x='Product_Category_3', y='Purchase', data=df_1)
plt.title('Outliers in Purchase by Product Category 3')
plt.xlabel('Product Category 3')
plt.ylabel('Purchase amount')
plt.show()

# %%
# Analysis by Gender, Marital Status, Occupation, Occupation vs Purchase, Purchase by City, Purchase by Age Group, etc.

# Gender vs Purchase
sns.barplot(x='Gender', y='Purchase', data=df_2)
plt.show()

# %%
# Occupation vs Purchase
sns.barplot(x='Occupation', y='Purchase', data=df_2)
plt.show()

# %%
# Age vs Purchase
sns.lineplot(x='Age', y='Purchase', data=df_2)
plt.show()

# %%
# Product_category_1 vs Purchase
sns.barplot(x='Product_Category_1', y='Purchase', data=df_2)
plt.show()

# %%
# Product_category_2 vs Purchase
sns.barplot(x='Product_Category_2', y='Purchase', data=df_2)
plt.show()

# %%
# Product_category_3 vs Purchase
sns.barplot(x='Product_Category_3', y='Purchase', data=df_2)
plt.show()

# %%
# Purchase by City
sns.barplot(x='City_Category', y='Purchase', data=df_2)
plt.show()

# %%
# Drop unnecessary fields/data
df_2 = df_2.drop(['Product_Category_2', 'Product_Category_3'], axis=1)
df_2
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000001  P00069042      F   0-17          10             A
# 1       1000001  P00248942      F   0-17          10             A
# 2       1000001  P00087842      F   0-17          10             A
# 3       1000001  P00085442      F   0-17          10             A
# 4       1000002  P00285442      M    55+          16             C
# ...         ...        ...    ...    ...         ...           ...
# 550063  1006033  P00372445      M  51-55          13             B
# 550064  1006035  P00375436      F  26-35           1             C
# 550065  1006036  P00375436      F  26-35          15             B
# 550066  1006038  P00375436      F    55+           1             C
# 550067  1006039  P00371644      F  46-50           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# ...

# %%
# Convert categorical data into integer using map function (e.g 'Gender' column)
df_2['Gender'] = df_2['Gender'].map({'F': 0, 'M': 1})

# %%
# missing value treatment
df_2.fillna(value=0, inplace=True)

# %%
# Rename columns
df_2.rename(columns={'Product_Category_1': 'Category'}, inplace=True)

# %%
# Fill NaN values 
df_1.fillna(0, inplace=True)

# %%
df_2.fillna(0, inplace=True)

# %%
# map range variables into integers (e.g 'Age' column)
# For this first we are merging the two data sets
df = pd.merge(df_1, df_2, on=['User_ID', 'Product_ID'])
df
# Out:
# Empty DataFrame
# Columns: [User_ID, Product_ID, Gender_x, Age_x, Occupation_x, City_Category_x, Stay_In_Current_City_Years_x, Marital_Status_x, Product_Category_1, Product_Category_2, Product_Category_3, Gender_y, Age_y, Occupation_y, City_Category_y, Stay_In_Current_City_Years_y, Marital_Status_y, Category, Purchase]
# Index: []

# %%
# After that we define the mapping dictionary for age range
age_mapping = {
    '0-17': 1,
    '18-25': 2,
    '26-35': 3,
    '36-45': 4,
    '46-50': 5,
    '51-55': 6,
    '55+': 7
}

# %%
# Now Map the age column 
df['Age'] = df['Age'].map(age_mapping)
df['Age']

# %%
# Data Visualization
sns.countplot(df_2['Age'])
plt.show()
sns.catplot(x="Age", y="Purchase", data=df_2, kind="bar")
plt.show()
sns.catplot(x="Occupation", y="Purchase", data=df_2, hue="Gender", kind="bar")
plt.show()
sns.catplot(x="Category", y="Purchase", data=df_2, kind="bar")
plt.show()
sns.catplot(x="City_Category", kind="pie", data=df_2)
plt.show()

# %%
# ANSWER 2ND

# %%
df_1
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000004  P00128942      M  46-50           7             B
# 1       1000009  P00113442      M  26-35          17             C
# 2       1000010  P00288442      F  36-45           1             B
# 3       1000010  P00145342      F  36-45           1             B
# 4       1000011  P00053842      F  26-35           1             C
# ...         ...        ...    ...    ...         ...           ...
# 233594  1006036  P00118942      F  26-35          15             B
# 233595  1006036  P00254642      F  26-35          15             B
# 233596  1006036  P00031842      F  26-35          15             B
# 233597  1006037  P00124742      F  46-50           1             C
# 233598  1006039  P00316642      F  46-50           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               1                   1
# ...

# %%
df_2
# Out:
#         User_ID Product_ID  Gender    Age  Occupation City_Category  \
# 0       1000001  P00069042       0   0-17          10             A
# 1       1000001  P00248942       0   0-17          10             A
# 2       1000001  P00087842       0   0-17          10             A
# 3       1000001  P00085442       0   0-17          10             A
# 4       1000002  P00285442       1    55+          16             C
# ...         ...        ...     ...    ...         ...           ...
# 550063  1006033  P00372445       1  51-55          13             B
# 550064  1006035  P00375436       0  26-35           1             C
# 550065  1006036  P00375436       0  26-35          15             B
# 550066  1006038  P00375436       0    55+           1             C
# 550067  1006039  P00371644       0  46-50           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Category  Purchase
# 0                               2               0         3      8370
# ...

# %%
df_1 = df_1.drop(['Product_Category_2', 'Product_Category_3','Product_ID', 'Age','City_Category','Stay_In_Current_City_Years'], axis=1)
df_1
# Out:
#         User_ID Gender  Occupation  Marital_Status  Product_Category_1
# 0       1000004      M           7               1                   1
# 1       1000009      M          17               0                   3
# 2       1000010      F           1               1                   5
# 3       1000010      F           1               1                   4
# 4       1000011      F           1               0                   4
# ...         ...    ...         ...             ...                 ...
# 233594  1006036      F          15               1                   8
# 233595  1006036      F          15               1                   5
# 233596  1006036      F          15               1                   1
# 233597  1006037      F           1               0                  10
# 233598  1006039      F           0               1                   4
#
# [233599 rows x 5 columns]

# %%
df_2 = df_2.drop(['Product_ID', 'Age','City_Category'], axis=1)
df_2
# Out:
#         User_ID  Gender  Occupation Stay_In_Current_City_Years  \
# 0       1000001       0          10                          2
# 1       1000001       0          10                          2
# 2       1000001       0          10                          2
# 3       1000001       0          10                          2
# 4       1000002       1          16                         4+
# ...         ...     ...         ...                        ...
# 550063  1006033       1          13                          1
# 550064  1006035       0           1                          3
# 550065  1006036       0          15                         4+
# 550066  1006038       0           1                          2
# 550067  1006039       0           0                         4+
#
#         Marital_Status  Category  Purchase
# 0                    0         3      8370
# 1                    0         1     15200
# 2                    0        12      1422
# ...

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()

# %%
df_2 = df_2.drop(['Product_ID', 'Age','City_Category'], axis=1)
df_2

# %%
df_2 = df_2.drop(['Stay_In_Current_City_Years'], axis=1)
df_2

# %%
X = df_2.iloc[:, :-1]
y = df_2.iloc[:, -1]

# %%
regressor.fit(X,y)

# %%
Predicted Purchase is

# %%
Product_Category_1

# %%
print("Predicted Purchase is")
"regressor.predict(df_1)"
